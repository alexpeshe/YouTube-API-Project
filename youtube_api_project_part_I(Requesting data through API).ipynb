# %% [markdown]
# # Exploratory Data Analysing Using Youtube Video Data from One of My Favourite Channels

# %% [markdown]
# # 1. Aims, objectives and background

# %% [markdown]
# # 1.1. Introduction

# %% [markdown]
# YouTube, founded in 2005, has grown to become the second largest search engine in the world, processing more than 3 billion searches per month. However, it is still largely unknown how the YouTube algorithm works and what makes one video get more views and be recommended over another. YouTube has a highly advanced recommendation system, making it a challenge for new content creators to understand why some videos are more successful than others. There are various myths around the success of a YouTube video, such as having more likes or comments or being a certain duration. It is important for new content creators to experiment and identify trends in their niche.
#
# As a new content creator with a YouTube channel focused on data analytics and data science, I have decided to investigate this topic in order to gain insights that could be helpful for other new content creators. However, the scope of this project will be limited to data science channels only, as other niches may have different characteristics and audiences. The project will focus on analyzing the statistics of the 10 most successful data science YouTube channels.

# %% [markdown]
# # 1.2. Aims and objectives

# %% [markdown]
# Within this project, I would like to explore the following:
#
# - Part I - Getting to know Youtube API and how to obtain video data.
#
# - Part II - Analyzing video data and verify different common "myths" about what makes a video do well on Youtube, for example:
# Does the number of likes and comments matter for a video to get more views?
# Does the video duration matter for views and interaction (likes/ comments)?
# Does title length matter for views?
# How many tags do good performing videos have? What are the common tags among these videos?
# Across all the creators I take into consideration, how often do they upload new videos? On which days in the week?

# %% [markdown]
# # 1.3. Steps of the project
#
# Obtain video meta data via Youtube API for a popular channel channels in the digital niche (this includes several small steps: create a developer key, request data and transform the responses into a usable data format)
# Prepocess data and engineer additional features for analysis
# Exploratory data analysis
# Conclusions

# %% [markdown]
# # 1.4. Ethics of data source
#
# According to Youtube API's guide, the usage of Youtube API is free of charge given that your application send requests within a quota limit. "The YouTube Data API uses a quota to ensure that developers use the service as intended and do not create applications that unfairly reduce service quality or limit access for others. " The default quota allocation for each application is 10,000 units per day, and you could request additional quota by completing a form to YouTube API Services if you reach the quota limit.
#
# Since all data requested from Youtube API is public data (which everyone on the Internet can see on Youtube), there is no particular privacy issues as far as I am concerned. In addition, the data is obtained only for research purposes in this case and not for any commercial interests.

# %% [markdown]
# # Part I - Requesting Data Through YouTube API

# %%
#importing all necessary libraries
import requests
import googleapiclient.discovery
from googleapiclient.discovery import build
import numpy as np 
import pandas as pd
import seaborn as sns
import IPython.display
from IPython.display import JSON

# %%
# Creating a variable for the api key
api_key = 'AIzaSyAoXH-pggHWClrMsxLrgOOP0Fb0JHFcKNg'

# %%
# Defining the channel IDs you want to get information for
channel_ids = ['UCP7WmQ_U4GB3K51Od9QvM0w']

# %%
# The code creates a client object for interacting with the YouTube Data API using the Google API client library, which requires specifying the API service name, version, and developer key.

api_service_name = "youtube"
api_version = "v3"
    
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Getting channel stats
    
    Parametres:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

# %%
# Creating channel_stats variable in otder to print the initial channel stats.
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
print(channel_stats)
# Out:
#     channelName subscribers      views totalVideos                playlistId
# 0  David Bombal     1710000  106653492        1243  UUP7WmQ_U4GB3K51Od9QvM0w

# %%
#This code uses the YouTube Data API to retrieve the details of the playlist with the ID "UUP7WmQ_U4GB3K51Od9QvM0w", including the videos in the playlist and their metadata, and prints the response.

request = youtube.playlistItems().list(
    part="snippet,contentDetails",
    playlistId="UUP7WmQ_U4GB3K51Od9QvM0w"
    )
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'ZAn0VuX5nL43lclv4_TZthy4Qfg', 'nextPageToken': 'EAAaBlBUOkNBVQ', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'wUf-NhyBZOk5AENf0UQourkLQsE', 'id': 'VVVQN1dtUV9VNEdCM0s1MU9kOVF2TTB3LjZtbWdpNjVPakJN', 'snippet': {'publishedAt': '2023-03-19T15:00:03Z', 'channelId': 'UCP7WmQ_U4GB3K51Od9QvM0w', 'title': "What's the Best Operating System? #shorts", 'description': '#youtubeshorts #linux #windows', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6mmgi65OjBM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/6mmgi65OjBM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/6mmgi65OjBM/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/6mmgi65OjBM/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/6mmgi65OjBM/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'David Bombal', 'playlistId': 'UUP7WmQ_U4GB3K51Od9QvM0w', 'position': 0, 'resourceId': {'kind': 'youtube#video', 'videoId': '6mmgi65OjBM'}, 'videoOwnerChannelTitle': 'David Bombal', 'videoOwnerChannelId': 'UCP7WmQ_U4GB3K51Od9QvM0w'}, 'contentDetails': {'videoId': '6mmgi65OjBM', 'videoPublishedAt': '2023-03-19T15:00:03Z'}}, {'kind': 'youtube#playlistItem', 'etag': 'PeiraRDmf2yA4loZF8JVG59a_pQ', 'id': 'VVVQN1dtUV9VNEdCM0s1MU9kOVF2TTB3LjV2RHVjQVNtT19J', 'snippet': {'publishedAt': '2023-03-14T15:01:00Z', 'channelId': 'UCP7WmQ_U4GB3K51Od9QvM0w', 'title': 'Flipper Zero Capture & Replay Sub-Ghz Signals #shorts', 'description': '#youtubeshorts #flipperzero  #flipper', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5vDucASmO_I/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/5vDucASmO_I/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/5vDucASmO_I/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/5vDucASmO_I/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/5vDucASmO_I/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'David Bombal', 'playlistId': 'UUP7WmQ_U4GB3K51Od9QvM0w', 'position': 1, 'resourceId': {'kind': 'youtube#video', 'videoId': '5vDucASmO_I'}, 'videoOwnerChannelTitle': 'David Bombal', 'videoOwnerChannelId': 'UCP7WmQ_U4GB3K51Od9QvM0w'}, 'contentDetails': {'videoId': '5vDucASmO_I', 'videoPublishedAt': '2023-03-14T15:01:00Z'}}, {'kind': 'youtube#playlistItem', 'etag': 'cHP8xinc_7xzDaGijZok5wPMz7M', 'id': 'VVVQN1dtUV9VNEdCM0s1MU9kOVF2TTB3LnVuQk9IUjdCandZ', 'snippet': {'publishedAt': '2023-03-09T15:00:40Z', 'channelId': 'UCP7WmQ_U4GB3K51Od9QvM0w', 'title': 'Do you know what a terminator is? #shorts', 'description': '#youtubeshorts #internet #starlink', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/unBOHR7BjwY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/unBOHR7BjwY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/unBOHR7BjwY/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/unBOHR7BjwY/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/unBOHR7BjwY/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'David Bombal', 'playlistId': 'UUP7WmQ_U4GB3K51Od9QvM0w', 'position': 2, 'resourceId': {'kind': 'youtube#video', 'videoId': 'unBOHR7BjwY'}, 'videoOwnerChannelTitle': 'David Bombal', 'videoOwnerChannelId': 'UCP7WmQ_U4GB3K51Od9QvM0w'}, 'contentDetails': {'videoId': 'unBOHR7BjwY', 'videoPublishedAt': '2023-03-09T15:00:40Z'}}, {'kind': 'youtube#playlistItem', 'etag': '2MMwnUo9sTcJIHIvenSA7Dc-1-0', 'id': 'VVVQN1dtUV9VNEdCM0s1MU9kOVF2TTB3LlpmejNaTjJkVERN', 'snippet': {'publishedAt': '2023-03-05T15:00:31Z', 'channelId': 'UCP7WmQ_U4GB3K51Od9QvM0w', 'title': 'The best Hacking Courses & Certs (not all these)? Your roadma ...

# %%
# Creating the playlist_id variable

playlist_id = "UUP7WmQ_U4GB3K51Od9QvM0w"

# %%
# Testing the function that takes in a YouTube API object and a playlist ID, and retrieves all the video IDs within the playlist, even if the playlist contains more than 50 videos (which is the default limit for one request). It does this by using the nextPageToken in the response to make multiple requests until all video IDs have been retrieved.

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
# The variable video_ids contains a list of video IDs extracted from a given YouTube playlist #

video_ids = get_video_ids(youtube, playlist_id)

# %%
# Requesting the video_ids

video_ids
# Out:
# ['6mmgi65OjBM',
#  '5vDucASmO_I',
#  'unBOHR7BjwY',
#  'Zfz3ZN2dTDM',
#  'tm4evj8MZvY',
#  'wjGFR38JFUE',
#  'bwUXMQqMXaY',
#  'z78TCiMrk2w',
#  'XjA-GIS9U5U',
#  'nHDixd-EdEQ',
#  'KCTD61OmnzA',
#  'evN89fdKOxU',
#  '0qFLgjfZ6Oo',
#  'yq9zo6IzP64',
#  'jpgKUqEwFsg',
#  '8MIIeIa25tE',
#  '0hKUZC6L99g',
#  'L-TJVyBdF2M',
#  'Q9LZZ4ur-bU',
#  'x7bSegjbfbU',
#  'OVwJ5EMTSK0',
#  'aQ_XTBmCXS8',
#  '-OAa9k0zCDg',
#  'NXpeXn0SKPU',
#  'Fw5ybNwwSbg',
#  'LWmy3t84AIo',
#  'BSugciSUIek',
#  'oz7NFc-qm7E',
#  'Clu3-5TFdw0',
#  'wGI5fcKzMWo',
#  'VcV4T8cL3xw',
#  '8HMqspTWWzc',
#  'Nvv0drH4lmA',
#  'tGZoCCoJtXA',
#  'trPJaCGBbKU',
#  '4ljq8JMFbJM',
#  'yKTzek8EZ4E',
#  'bK1lsI-ehL8',
#  'I3Zd2LF1OAE',
#  '20_7tit3IBQ',
#  'WqbrB12Jvgc',
#  'VF3xlAm_tdo',
#  '7GGLi10sHDs',
#  '3KYZ5yEqvY4',
#  'L5Tn4jU9wz4',
#  'QqrK294l_oI',
#  '1Kg0Eh7n-RM',
#  'Wx_aTsJr75c',
#  'yHT4kq36PE4',
#  'EMFIUDfQHCI',
#  'UYt0r5Rw2gE',
#  'F6l2Bmh7Dq4',
#  'yDwxmF0Kn-Q',
#  'f2BjFilLDqQ',
#  'ObUgYDn1zZ0',
#  'gii-IMlv6_Q',
#  'Qb8Wvo9u5zE',
#  'To5Nbs6DmIA',
#  'wikyhVFPiDA',
#  '5LvqU3-iINk',
#  'nyhytT2tRN0',
#  'TuIsHKUkI0g',
#  'CkVvB5woQRM',
#  'LBM3EzBXhdY',
#  'kVSCFBuh9xs',
#  'KxOGyuGq0Ts',
#  'PH9RQ6Yx75c',
#  'idy5mE-fypE',
#  'cdb7M37o9sU',
#  'jPucxDfCk0k',
#  'sxCUZFVM8xk',
#  '7V9_x97s4g8',
#  '2B76CTbi72w',
#  'OsY32K1s51Y',
#  'aesAJAhXu-A',
#  'U6pDqFhN82I',
#  '7iBqoc-DzTQ',
#  'ANPtqTNLAY4',
#  '22pXJYO3qPE',
#  '9kJKi0MepXk',
#  '3yiT_WMlosg',
#  'rIsXBLlHdgE',
#  'CpPG0KtPNhw',
#  'FtOgJm8ez68',
#  '9fqDUrJWR9o',
#  '7FeNCmrRmdQ',
#  'YIPaZZkozz0',
#  'SiFyhipl57A',
#  'ZGCScbV7vSA',
#  'J-gnDC6B5eE',
#  '4VaHN4CG34w',
#  'PzRQhpbYbeg',
#  'ImWJgDQ-_ek',
#  'CIWD9fYmDig',
#  'uXbGQiXsRes',
#  'tV8CxS1YB7c',
#  'z3o6yEzcnLc',
#  'yYY5mJoUZjU',
#  'aEss3CG49iI',
#  '9vaEwycet90',
#  'Qr1nUxdzcbA',
#  '25_ftpJ-2ME',
#  'GudY7XYouRk',
#  'F2PXe_o7KqM',
#  '-2eVJRBNzY0',
#  'xhL5Usvklpo',
#  'ZTIB9Ki9VtY',
#  'UXyS-xofGNM',
#  'Usw0IlGbkC4',
#  'PqRVo2niA_8',
#  'jjnctE9XZ_E',
#  'rmFX1V49K8U',
#  'jGgmlCO8gqs',
#  '1ffv507slWM',
#  'Ym9dOW6TnkA',
#  '6llnxOV_aRU',
#  'APlR80rT6fU',
#  'mS7qWC3CbOU',
#  'KhwJ6fD-t10',
#  '8mLt3QPZJtY',
#  'efnluUK_w_U',
#  'qaZ-IbssPDI',
#  'A_itRNhbgZk',
#  'yodDbgoCnLM',
#  'GMNOT1aZmD8',
#  'es7hEYS1woM',
#  'O1jpck31Ask',
#  'B09CM6KaAuk',
#  'FDAvAWrAu88',
#  'G8lrwmsx8KA',
#  'dXqD_jUwEGU',
#  '5xeNeQa_qSY',
#  '2W_YE0fZs88',
#  'IFYBIjjXLbQ',
#  'FwSNe2sQcg4',
#  '39DGVpMt7eQ',
#  '7YpJQT55_Y8',
#  'bGpKCFIVYZg',
#  'QGOSBUo8Nzw',
#  'sBuxwMAfGnI',
#  'Cr43jXsERQU',
#  '50JVH9Gx7CQ',
#  'r2movJrfvmI',
#  '4ZWQrjijcZ4',
#  'HUEOEZGFNdE',
#  'Ecf0tNoYemc',
#  'QE6E9ZxBAwc',
#  'VW0szfPHeo0',
#  'RWH_GJneCn8',
#  'u5cp_hcwq2c',
#  'Ay6fVYpYlkQ',
#  'SSFwPLs1HKA',
#  'YKxKnVE5FaE',
#  'nwbQE4mvJRo',
#  '1cX82-xN7b0',
#  'g-8fAQHL-Uk',
#  'v9lj2d9gpsw',
#  'XUncozRGbcs',
#  'Q0sxqze-8tc',
#  'IWWYNDiwYOA',
#  'hKPKvg6bctU',
#  'W6_nBr8SbPE',
#  'msO-gmd3Qyg',
#  'Y8G-SleiyUU',
#  'MHfylRCfccM',
#  'WAVjcY9_UeY',
#  'MpN6Gge4EG0',
#  'ES2P2hWuzDo',
#  'ZUqGSbvZp1k',
#  'HKCYs-UKU4Y',
#  'iD84waJKYh0',
#  'u4u6ob13s2c',
#  'yq561bLg10A',
#  'fffSbCbafts',
#  '_VITu5opI8Y',
#  'qiEMdGhYIvM',
#  'fcrSmbUIHuo',
#  'tYnjMiTTdms',
#  'hEXwOkyYNL0',
#  'UA-IJ8DWh_8',
#  '5MOsY3VNLK8',
#  'fbxP2nI3bt8',
#  'iGXB5NanUK4',
#  'HemWKwd2AvM',
#  'uMZSfivlyPI',
#  'x4AE5yOF9pE',
#  'EKpyXPqfxIc',
#  'DFTwB2nAexs',
#  'LzooeiGxKis',
#  'rQCH7gTPCfg',
#  'Oh2OmtN8jj0',
#  '7BaYLX1MYBQ',
#  'EtVTPonfm6Q',
#  'l6xWt_7mfo0',
#  'uBzKDF67eWY',
#  'jsMp65-piIc',
#  'VrayWzHKVw4',
#  '0ouVxR7hLvE',
#  'nMqRmXO2x3s',
#  'WfYxrLaqlN8',
#  'ZIqvGmrw7Tw',
#  'vlqmC1aEUSk',
#  'vAsYQGtbBis',
#  'XLsh1bgae4k',
#  'SFbV7sTSAlA',
#  'wNAEziRil6E',
#  'zu8wQPffQ8o',
#  'SzYKzAHsdMg',
#  'QTYML8B8UkU',
#  'LW56JL4Jsig',
#  'aSGsMBX-zuQ',
#  'QVdXrZcmaiM',
#  'LbEg23PpP6E',
#  'n2olKupv9fY',
#  'FzkLILpNGZw',
#  '0HS2J9mQmcU',
#  'o22R6yFr3BA',
#  'sjB6DFwQHBo',
#  'xgE1T8xxhgE',
#  'ScEjaKqQDwY',
#  'J8A8rKFZW-M',
#  'Kbw6QK-oRQY',
#  '3K1hUwxxYek',
#  '3_f-SWQP3x0',
#  'IaUTKxPpygU',
#  'mIdF7K3Nmlw',
#  'rgWcguAg-XA',
#  'Ezy1KTNF6dw',
#  '-WefgSx_eKY',
#  'Ny8j2iVlX_s',
#  'KxaXqLVnZQk',
#  'TDVM-BUChpY',
#  'XKoTwepEzPI',
#  'gbwp6xkYRvs',
#  'eyd24FlJCFg',
#  'X990ZNA2Tog',
#  'A2JNBpUotZM',
#  'Y2fhWtZedTQ',
#  'EGlq6J1E7no',
#  'jIRRsIgfHU8',
#  'uZI9ZnKRudg',
#  'LfZNhf2Yc8k',
#  'PoaOgBmWJQY',
#  'nGEKnYUEPcg',
#  'bqF0zoGTaY0',
#  '4Jr39BTk5qE',
#  'VAMP8DqSDjg',
#  'V5mBJHotZv0',
#  't9C6tXQg0vg',
#  'nXThnFxwH9c',
#  'QHwPaLChvgw',
#  'tA50zg7D4mg',
#  'hFFhL-WktoY',
#  'PN--Z6A0-Iw',
#  'eO_xmghwyj0',
#  'TjW7yCqsHr8',
#  'tM2aUpll1EQ',
#  'Toa5-1i4wRE',
#  'WdBBYosG-YI',
#  't49mCGDTOGo',
#  'IdEFDkGtcQg',
#  'MRpVO2dZ_ks',
#  'Nj-yeK1nU8o',
#  'qfWSToryDos',
#  '9CY42I04MFw',
#  'BLbKKvyjk5U',
#  'rtm_Bofv4-8',
#  'kg5CalaPOLA',
#  'QXfaGOMT7MY',
#  '0LrTZfetZNo',
#  'hdM-citojaI',
#  'apr63p7K_3A',
#  'gdV0T91Bvt4',
#  'CdoG4tWNPqs',
#  'IB1uKovH_Lw',
#  'Cahex02YJc8',
#  '0wOWJg3-cDs',
#  'X6B-MkLWId8',
#  'klAfyg5mhro',
#  'zxZpopqhKk8',
#  'w8Jm7wVH0Rw',
#  'yCK3easuYm4',
#  'IL7Jd9rjgrM',
#  'B1tCRwkFmnA',
#  'YFxcxuL52SA',
#  'A1OJpkCgagc',
#  'oTD8cYluUgk',
#  'bAcSnwmB_4Q',
#  'uWNpXOT-Zbo',
#  'GFgJgGV4d28',
#  '5RQbdMn04Oc',
#  'ioay-ArwCQ0',
#  '_fntjriRe48',
#  '0G8G9SnPT9k',
#  '-TxcYJhWjFU',
#  '29DeBKt700I',
#  'pyq56692bs0',
#  'umsYXQGV4-g',
#  'DAajWlVcskw',
#  'kZ4YqqlU5eM',
#  'oxZa1oSGUps',
#  'ynRIpyvD5qI',
#  'H1N1x9kt-pY',
#  'Bqd901dKIB4',
#  'p-3QHCt1L_w',
#  '5iA_ZBcFwEU',
#  'ur2G0dpMCBs',
#  'NvqD0wdQlYA',
#  '8_R0gmpM8eI',
#  'skE-rfw4PRc',
#  'T6aHuGfo2mI',
#  '_Z_OHL8lBqQ',
#  'Ypk77FytrWw',
#  'LD9oJPyP6iE',
#  'uE7-FgLxlyk',
#  'DySVOlFPHbU',
#  'wDvX8yVr6yU',
#  'GqWpK8HVXzo',
#  'Q-d1Ctdwxg0',
#  'sW5-jHLygFg',
#  'NbT_mdc3uko',
#  '3kz7B_sayEQ',
#  'uKhySSs08tk',
#  'OLqbXJTumpo',
#  'V3Pcc8b_m0U',
#  'unc36O66Ef0',
#  'S6KI6VsvDuU',
#  'dl-C6cBoRg4',
#  'JMT2qimIL9Q',
#  'u_LrU1Mr5hg',
#  '1YAicAJEqM0',
#  'DGVCdwyOuCA',
#  'cxQvzJiWM70',
#  'LqfS29tab9s',
#  'XJ9HA8Fxo74',
#  '53z2fNgLS6k',
#  'yTINu4UQz4Y',
#  'ns7TYxNcYBM',
#  '5sa0acU4pmY',
#  'g9OGphrEMb0',
#  'U3Wr2gfIUXM',
#  'K1bMSPje6pw',
#  'AnwgxRtWXLI',
#  'b42VMQZpiKk',
#  'YKYdq3Ww_C0',
#  'FDbgTlr-tnw',
#  'fnQB6cN3UWo',
#  'jhh2_PP9JLU',
#  'A0DEnMi09LY',
#  'Ibe3hgP8gCA',
#  'HfBsNHQPJR8',
#  'JJjTByHN2iI',
#  'vgG87eHstUc',
#  'icxtwYS25aM',
#  'Dp2mFo3YSDY',
#  'fiuD-LAXcAw',
#  '-y-HUJOI8i4',
#  '5vmgNL-w_Vg',
#  '7pvUWJwYb-o',
#  'g9ZtTd2v29A',
#  '31XuFB50oe8',
#  'eb6uHH4DOeA',
#  'UMjKT84BxY8',
#  'xwggbwoui1Q',
#  'tKIu42nOtPw',
#  'N7xlwUhvX7o',
#  'ABoiRa5cW2w',
#  'CtuhArLfStc',
#  'SWCZWqCNB5k',
#  'zRk5dymfNsk',
#  '4_7A8Ikp5Cc',
#  'rgxeyCbm15Y',
#  'eColtgrsico',
#  'nxuE3pm4Rtc',
#  'K-iAD8B5noM',
#  '5xUvqDMxH3g',
#  'fnhOYC0SS2Y',
#  'M-z8-H_LbiA',
#  'HoYgPlmOZgo',
#  'zUBaLnQwbpA',
#  'anYw9pbAUiI',
#  'R6fSub4ycTk',
#  'LvLGEKD-oqA',
#  '23hPg88pZBo',
#  'eMb1IzOoEwc',
#  'sxaHtjJfAzg',
#  '-2JylWwD3qs',
#  'JT64JiZWNgY',
#  'PqhTADCv56I',
#  'X5P0fl1ul0w',
#  'IuwbQgS7YjM',
#  'Okae6K-nbRU',
#  'PVIjuR0ZPI4',
#  'bNEOMXXqLv0',
#  'YqXo8BYAu8Y',
#  'BJPtYh330AM',
#  'ZVKy00NMdto',
#  'r62vs2uyQjM',
#  'uZMA4p00c9g',
#  'ftrZM3znTQ4',
#  'e6fqQQA2Hu4',
#  'jh54TRHkBE4',
#  'PB9D4RqBaQw',
#  'grS__DS3v7c',
#  'qbE2NaBh55w',
#  'wLqiUC4FMA8',
#  'jsh4XUPZTWE',
#  'iwl3XF-8r2g',
#  'unOmwDsMj8k',
#  'C0KBYSOLAM4',
#  'Ql4ZI1BSSTo',
#  'CyLZa_DPi_8',
#  'BeppwCjOjyY',
#  'P7pl-hb5-ik',
#  'hEbokePjQhA',
#  '7OoGuLH9IwU',
#  '761glRrJhX4',
#  'BmnRf0HCy_Q',
#  'YG8MmTTjikA',
#  'ZV3sIZAtaz4',
#  'S35HCSkzijU',
#  'rFt660zikRo',
#  'B-GKA3hSN60',
#  'ivPL6_NHG34',
#  '_ZCFJtE_FXM',
#  'g0Ms6MTHpbk',
#  'TmGNtvh1eeY',
#  'X_P47gEucVM',
#  'U9hw0gustB8',
#  'Etl7UEKJRjY',
#  'sErFiilXku4',
#  'N-Zn2V6T8AU',
#  'YB_UGPDcXIs',
#  '9tNrBLZdoMM',
#  'jSUb0ZkN0ec',
#  'hCRjDwuuQOA',
#  '1j_NrzowyeU',
#  'q_QJb37SRig',
#  'cMR19vkNqS8',
#  'FVOC_LOgAdQ',
#  'uOUgGzSmruY',
#  '9hj7_0fOfZI',
#  '5pO9cE5KRwU',
#  'UalITC822cI',
#  '51zaAHhdgzQ',
#  '5SvfdMhl_eE',
#  'bZKTRIF7UJg',
#  '9s5CURvysic',
#  'FwsXP_sZLaw',
#  'X4kLcJqtrXc',
#  'UZCirsmQdvA',
#  'HOD3NYN1hfU',
#  'vMUrSUpqjQU',
#  '5CeIeIM59jY',
#  'yHnok5ZEZug',
#  'E09VFtuvrEE',
#  'S0jfZLobFdU',
#  '-uXJo8bD0Zo',
#  'O3yoHjkBRxw',
#  'JRf3hVhfj6Y',
#  'XBSrrc4Q31g',
#  '7BDtElBjXRc',
#  'EoU8oEmYD7s',
#  '_rPKmjGhAKw',
#  'xDKvqQIQy90',
#  'RjITDcA_VVE',
#  'vE5unuqIauE',
#  'xVVuW57ccko',
#  'BiEEZ3KIhJ4',
#  'GWiUsZXF-ZY',
#  'd0G71-t3tcU',
#  'NcwsYHqp4bk',
#  'drUWlIz04zo',
#  'nHImxqKSJlg',
#  'aDPogE0CSfw',
#  'PGFtP9u3MZg',
#  'txf9M4Ud9yU',
#  'cooE3wZ7O4I',
#  'shoDldraAsE',
#  'Q2TnxcJa0wI',
#  'mQKbXMIxHSk',
#  'iuev1Hyc-f4',
#  '3utfGQyQOkA',
#  'lN6dymX7t9k',
#  '34cXIKiVgXw',
#  '2Yh9K6NisHw',
#  'zeuRSqkPV5Q',
#  'JLuTRzeh6Nk',
#  'haCk1oBG394',
#  'o3CaEaVfCP0',
#  'Tarqb6uRvX8',
#  'FgGpFozmjAM',
#  '8Evz8tWAqSk',
#  'HI72nwxj_zs',
#  'EZfUtBxR_1Q',
#  'Ie5GwqtUVc8',
#  'g4gvu6AYYpI',
#  'Buj8qH4emHM',
#  'NKGzc7BSKSk',
#  'dLkXxy1zWaI',
#  'oEP5eXftWJI',
#  'rNxOLi966tI',
#  'amjoJT-HVaY',
#  'VTItF2PbsFc',
#  '2jKmWGtKNj0',
#  'O3Aen3EOymc',
#  '-VXZIkers6A',
#  'LnubwpNAuTI',
#  'S_K1mYHOoW8',
#  'QoYoz_mL2Ak',
#  'Kg_u_8VUv10',
#  'bL30fRiPQ6E',
#  'RFGbZU6lIJs',
#  'jtXUVdwKSvI',
#  '-RNDhWxX9n4',
#  '5h0fN0j2XS8',
#  'GD931kNzw98',
#  'BwT2UQjgkSU',
#  'DQR5EqM1doQ',
#  'PN-uloEHfgk',
#  'LbvAf9vK2dQ',
#  'RY4RoeoWQQs',
#  'Kua21h5dbKM',
#  'ljWHFwo4wYQ',
#  'IBun7dykayU',
#  'x5REbzj7v-Q',
#  'DN5HCA7Tubc',
#  'vu7tQBmqg4M',
#  'N5N4C1Kr1y0',
#  'Vj5u8KlfJzU',
#  'jd1tCZlXzsI',
#  'o9tG1dHzdEY',
#  'a8SSs6lB-2s',
#  'BpKyAiBQRag',
#  'C5wV7VbAd4U',
#  '6FFFiA_DZ2A',
#  'Vg1LyDlYNK0',
#  'Ir_kBaZmSzE',
#  'z65ZJ_AljIg',
#  'RfZw69_dB7Y',
#  '6QCt3WbV0lc',
#  'vy-MYMi-9EI',
#  '0zri0AedQwo',
#  'AqMlRY1UZxI',
#  '9MMOPsg3OH0',
#  'fTxnL2EvEMw',
#  'biQzsNcg_UU',
#  'Ddu90PFe8F4',
#  '8dJc9FXXapk',
#  'CpaTF9sNOcI',
#  'tkqynFvkaks',
#  'vmF1sY78NBY',
#  '6EipZvCi9wQ',
#  '5mvO8_ay2VQ',
#  'QglMQpzKH5s',
#  '3yFVfP4Ygug',
#  'w51HYN5Xeh8',
#  'DcDVagk8Qsg',
#  '0h92_8Vaq7o',
#  'bD8cuQnQJIc',
#  'NESQR2-oSBA',
#  'x2HSOxkAKTQ',
#  '9qaAO5qFFig',
#  'qN4y7Y8Qrrc',
#  'LbBp8rHjais',
#  'm0xSWEeFYqQ',
#  'af8jF_ris_w',
#  'eu9iUE9gf2Y',
#  'cck5WO_KaDA',
#  'G1sOLwVS5GU',
#  '24of6SK6n30',
#  'ekEObaDLjYc',
#  '2e2LpeavZkM',
#  'J7YJ5a4-uz4',
#  '0-OKFego7r4',
#  'CP6A1I8AjfQ',
#  'pmwM3XjAw8s',
#  'kg_z1Rn57d0',
#  'EBa66YzpA4A',
#  'vNzZ9lfkRxU',
#  'Yr0PGonzbNs',
#  'sTEKHzfX5Fc',
#  '86MIuxQ-LtI',
#  'B_m9ROrmgWo',
#  'CzLbyvmwlfg',
#  'NMe7wyPkQRI',
#  'GmwqU2k-YuY',
#  'wKtA31whDSQ',
#  'n32MEMfWU9M',
#  'ERilHiKQkmw',
#  'yChJzhRXo9Q',
#  'itesC6sumV8',
#  'Q-vsZK2QQ_A',
#  'sShx34Yn14E',
#  'ffdOu_wbwXE',
#  'ypW0KoM0DYQ',
#  'fogXBd9_Kl8',
#  'u3EmleryJ9A',
#  'v7oabLXoVyA',
#  '9uFZ8arTYGE',
#  'lnoOQLvQctU',
#  'nCkOLjpCb84',
#  'RmfvX5DIRnc',
#  'JYLdSMdR_90',
#  '4kUx9DDf9hE',
#  'mu3fYGzwWVs',
#  'nxr5ER30rJA',
#  'jyiz-wJUmtA',
#  'vjNmn0sQOnw',
#  'WaS9BRNb4Yw',
#  '4iOmdnKQGpk',
#  'JFf-lYYhQi8',
#  'SEsGssgoq5w',
#  'uqtTgj9X-GU',
#  '9igSuEqpHE4',
#  'sZvOENclTpY',
#  'lHb_LfEVYnc',
#  'KVFrO0TvTAk',
#  'ciU5kwueAWg',
#  'e-4M5qX2Juc',
#  'l8b6FJbN83Q',
#  'dKS6WcIs_7w',
#  'ZI6qtCjQrww',
#  '5Ncgoc8dxCk',
#  'sY3C6eiLJrg',
#  'qfVFJjh40sY',
#  'roeFWYWP674',
#  'Dv5GYtHDscM',
#  'OozVF1Humu0',
#  'JWFPD5xy_z8',
#  'D1Ioxg_PoOY',
#  'y6CjmHtwuI8',
#  'H9ZVPydriG4',
#  'PZVnaucwYg8',
#  '1zz_cC0DUmw',
#  'AYw733Za4Sw',
#  '_uodNUKtcBY',
#  '-XD266iu2LA',
#  'bpxSeO8TNHE',
#  'hb7mMmBbGOE',
#  '3Qct-bpC4xs',
#  'Fk0udX-FqyU',
#  '11JX8cSwmm4',
#  'pMNab9y0lKU',
#  'yuWVNYw1ybA',
#  'HHI0U7HkYKs',
#  'ljy43Ndu5N4',
#  'rKuAUo6BFMM',
#  'PKbjjO8yPEY',
#  'AA2mquoXQr0',
#  'hrRqPBv_f38',
#  '5bYIcl9mr38',
#  'VoOrx9GNPfU',
#  'n9tj-1nSuSY',
#  'YMJmuj2D4VY',
#  '8AYLM2-LT2g',
#  'FIEc0r-aAPo',
#  '_RVdZxBoC3c',
#  'Ol0IFU-nJ3g',
#  'IwUlnxvTUU8',
#  'aXtWprR-iI0',
#  '_NJZzCeh0DQ',
#  'K0QGNeO1RIg',
#  'zQmmq5HcQbQ',
#  'KPrB5-Cjwuw',
#  'QhS2BSSuJT0',
#  'AkhUcTihfkY',
#  '360_7omXkPo',
#  'QcTjzetbLiY',
#  '9qKwDQ9Wev8',
#  '_q2PZhTyV4w',
#  'ju5OA4NIYbs',
#  'vHcPS3CB9h4',
#  'FWinJ5JILM4',
#  'ywLOCAbOOcc',
#  'kAnGDqws9Z4',
#  'c7vywj895tA',
#  'hPjueOEweBI',
#  'SlI9o5YGLwI',
#  '-6WCUMdvGlY',
#  'S2ozYFm5t3k',
#  'bxihPqtgjg4',
#  'vUceekKxLOM',
#  'sm90qg07fto',
#  'Mt7bSJzu9q0',
#  'Zo8FZKL_uqs',
#  '20sxQ8eWp74',
#  'F5vEttMAE7Y',
#  'qb3bu75LqNU',
#  'D6pmIflDSGI',
#  'eQ0r-2FPs9Y',
#  'EcvignZpNQ0',
#  'oykn34huRrU',
#  '8jg4_TtsEPQ',
#  'YQcWuWGjppY',
#  'f6wVPW6Hejg',
#  '95cWjdpQLTg',
#  'C9JEq6CBaJo',
#  '-pwuIkdZ3Cc',
#  'sA2_gX2ju-s',
#  'lFEDmM_lsxI',
#  'Yg_2F6r9UpQ',
#  'Kg71q3hANQ8',
#  'AAsHHn4ndPo',
#  'oC8aGteHOPY',
#  'wdihCne_rP4',
#  '0xwVQeI2yrE',
#  'zbQsx-zcug4',
#  'BU5x_EYIIGU',
#  '2-_OyvR2NzI',
#  '4YXa_UC-YXc',
#  'cYATFZPimIw',
#  'x9pGYyEqLYs',
#  'RGxO3J9qi-A',
#  '4-zVmYmyMMc',
#  'CnZxeC32pIM',
#  '4tYD4BIdSc8',
#  '6D_IF3R-tfU',
#  'atZKZrf8fHc',
#  'zrkDbOTJoFw',
#  'BM1QgIwQj-o',
#  'pR5xEaVejWA',
#  'FhIj-8wLlHA',
#  'T9TPjPftEGE',
#  'AJfwtXf3vm4',
#  'ORr_rGnF0CY',
#  'QIuZdAcLXs0',
#  'KSnfNT41Ujg',
#  'Q7EHAzecMos',
#  'bW_DngbR-Pc',
#  '8TCwcS9Lld8',
#  'vBSaJbqCO1s',
#  'tL0ZRaa7Emw',
#  'psf7jVmq6B8',
#  'E6sp9Kcr22c',
#  'zXPROEwa6yg',
#  'cCoDxRbU3cw',
#  'nU1tKq_e2ro',
#  '7B_IfluAFug',
#  'XMuI8ZHjEy4',
#  'wCcnZ23U5m8',
#  'KO46Gd6A3u4',
#  'mo77eDMcrng',
#  'RZY55k8m26o',
#  'yobWaIHiGGk',
#  'fQUahaB182o',
#  'qxUQZJ0Rx9c',
#  'vKXpsv7LvEE',
#  'LjFNF8mbPpA',
#  'ijUZwjhLMag',
#  'mYKxsn7SV1g',
#  'be751FHxkg0',
#  'vatrTyGOUGg',
#  'pieAEOhHIvU',
#  'ALDsRkjYSrc',
#  'rw-uZi3zYSc',
#  '1nNHYoeXM6A',
#  '3vFdq3zxz6w',
#  's06UMYcu6PY',
#  'is7jyu4Eai8',
#  'k3Q260yypM8',
#  'HUFOHgCX_6Y',
#  'hzagfmCrXQ4',
#  'TlaxqFU9KnA',
#  '1xScu4_g_o8',
#  'k1_GotdCQZA',
#  'TGOKK5Tmzlg',
#  '0LDMZeiCkeU',
#  'WACZqTpZqqQ',
#  'flZeJrgMpMI',
#  'I0TxPExNLiA',
#  'L-LCC2UELtU',
#  'cYWnJdaiZQc',
#  'Dolh8-vYd-g',
#  'Nk26z4Xh_BA',
#  't8pmG7C-2X8',
#  'BjtzkzlyB5E',
#  '4FXRyjkM-IY',
#  'wJLahJTvBnM',
#  '_EblCywJqBs',
#  'Mr4xld7NmN0',
#  '9UVUt3_gX2k',
#  'JOp3iBDWoHo',
#  '2Lt1aXpCzvQ',
#  'PRHClwLsTss',
#  '015D4tTd_n8',
#  'UzqBpPP7_iA',
#  '6_wHw72wyrU',
#  'qKD0ebmmYos',
#  'aJmiXz-0zfM',
#  'goGpoqq266w',
#  '0nIiEs57kVE',
#  '39rIF1gtc04',
#  'C07yL2YIqsY',
#  'Anc7ckVO_kI',
#  'NsnVpN2WIWk',
#  'bCmxrFlxwNo',
#  'ht1vqcXaqPM',
#  'i6p8-qwmCMk',
#  'z-IrTVIi0Ew',
#  'wp6sCed-vyM',
#  'bA_6C3K31i0',
#  'C6oTnT0YDs8',
#  '9msAkdBOzJY',
#  'DJWj_4kpjBs',
#  'KxxdXQQNj8o',
#  'KN9YE1eoz94',
#  'zmPZiiC0NgQ',
#  'jSYPHA02OY0',
#  'idJYEnbbXcE',
#  'pbdF_4YpRJg',
#  '_3XIp6bw58s',
#  'UJ4Z2DODKgs',
#  'giGXCZ2yn6Q',
#  'sXEOtT2GBbc',
#  '6Xroig-W328',
#  'BDuIf1uD_cM',
#  'TT019ds3WF0',
#  'KNf_sTxlqtE',
#  'qDGxnWE5tHE',
#  'tMxCV4l4a_o',
#  'X8s5_YkNn5Q',
#  'M8-8l1DPfog',
#  'Gpje9PV1j8U',
#  '7HGETDihYkk',
#  'Pcksyle-roE',
#  '-f-feat5uHk',
#  'o2zyjNUE1bI',
#  '234u7nPbR7g',
#  '0Rq2tgyKbh8',
#  'XSl9KEmx_4s',
#  'ToVRZIWLx5U',
#  'zoBwqDVQ3yY',
#  'LkBf8gAtueI',
#  'Lny-xIK6tWc',
#  'H1w0m4u_olY',
#  'Y7ymcU3T02A',
#  '-1sfBNshpgE',
#  'Xw1rPaY9kks',
#  '1gW9r9gxXKg',
#  'lR8u0tvSfic',
#  'FgKuy9QElQU',
#  'TT9oG4UrJXI',
#  '_iuz6x2vBSw',
#  'qsXDZTPnlro',
#  'twpCQHOqVMs',
#  'ybjS8GV6k5g',
#  'meygA4aEN5I',
#  'nWnxKHmaGNU',
#  'KyxJ3l7GypU',
#  '5MzYIh3FK2g',
#  'shvkbqKVkDQ',
#  '3-NwdYgIsw4',
#  '_o_1XLt1hi8',
#  '-1Z6ygHO--8',
#  'TArIz-o04KI',
#  'uLbI7sS9szQ',
#  'fSBdr-0STYM',
#  '06wQQN1eXcs',
#  '7DXDMQRSnJU',
#  'mUwASh31aaA',
#  'Rltdel1tG-I',
#  'vH8Eribmghk',
#  'P6CW8hn5b0Q',
#  'y2AZYOq8Ni4',
#  'JmWLhmJSuuI',
#  'txRKuEGU7Ac',
#  '6HmSzPjqFaw',
#  'b6p6Q01zsZg',
#  'YN_nK3w51Ag',
#  'UnwEtt5EQOY',
#  '2XW1vOD3QyM',
#  'ldTLvTF2JEw',
#  'jclRq0MQAKE',
#  's7CkW9DNS3E',
#  '0T9YZssqDyE',
#  'viQ6wkfFGxU',
#  '6tmfzO9Q2cI',
#  '4ukwpvCuxHI',
#  'C0kJDtD1R9A',
#  'JK-VIgyS6AI',
#  '3HpyxBFaWjU',
#  '8Kf45Z9pQ94',
#  'et_DoqT6ulc',
#  'kXtTsYlryu8',
#  'IU8CJcCZlBg',
#  'xXkWsZiRfVk',
#  'AdRQ21lhTs4',
#  '2NMdIDmmOc4',
#  'sjOGz8BTVTs',
#  '2PkiHDRQZCU',
#  'bbA9IF271mg',
#  'Q6sHeCnFHSI',
#  '4F3qFjtRNyg',
#  '7TENqu3VoXQ',
#  'kJFSRPFGSu4',
#  't8hR3jcY6P8',
#  'Vj_BMmnJYsU',
#  '8wvtPTP5X84',
#  'tWTrGLnLV7A',
#  'vjY34-T1ID4',
#  'wmjNvOp5kxc',
#  'VZMEFxCgTEA',
#  'OxdB3K3xsEM',
#  '6MdLD2cnPGg',
#  'UE6ISfZ_CUM',
#  'KQhwPfkZXz8',
#  'H7QMVlJElAU',
#  'pgCyYuoeY_E',
#  'c3BG3IO4w4o',
#  'fjWkcIjJNms',
#  'qDd8mHLCqK0',
#  'lY-dIxO_P90',
#  'EcTHmOqDWvY',
#  'Gk6Ef7AV-yU',
#  'ZK0KsqxsHAc',
#  'UwvZHLghW4w',
#  'fLiXCOWvwec',
#  'sMT1qkCjcSM',
#  'MYiayHomAaU',
#  '6RsSIEatNts',
#  'd1_KwxfWx1A',
#  'svTMfrsPOPE',
#  'IE9aJH3uhnE',
#  'E-J8EPUvc8E',
#  '9uUK0nwuLrk',
#  'S4NtYBHb3gs',
#  'TmNsM8w7R38',
#  'tpwVjwakJG8',
#  'NRt06ms2ZPg',
#  'I-R3I-BweDY',
#  'MXlMKRawOm0',
#  'zpg4mZ6qrlw',
#  'Ke6dXprVuBs',
#  'zTbJaFCbvME',
#  'qAi7K4-N8Sg',
#  'L_YfSU378yI',
#  'gEVFRBnjpS4',
#  'C5AlMvhIeXI',
#  'QqUYCZjSxUs',
#  'IQctXVwKboA',
#  'GN8aTXMdycY',
#  'ewGC6W7wiVY',
#  'FERL_NFOWio',
#  'xd1kI1eq5uw',
#  'u-gNgQsGUi4',
#  'czYa2MZwrdk',
#  'XOGzUMzuhT0',
#  't-AjBM9P8A8',
#  '9nYgGGh1SJc',
#  '9IaKIzGaGsY',
#  'sa8Sti-90xg',
#  'Mzrv7W4TLbU',
#  '60QB6z8ZZGo',
#  'LsHcYzYNn9Y',
#  'Cf5HeievDAs',
#  '0bwUpR6-Av8',
#  'z4rSYkuYljw',
#  'LiShXliOSvI',
#  'Mu8lLIdTQ90',
#  'sKEaCN_Mrl8',
#  'hZmZq1Gr5zM',
#  'dE2afwB9d5U',
#  'ViGoIl0-g7s',
#  '0hY-iajBhiM',
#  'VV9Zi-5kY9Y',
#  '_XGtQRUWasQ',
#  'huxQZoneWvI',
#  'IhroIrV9_7w',
#  'o_jyIBbHTSI',
#  'vxUbv5QcOEo',
#  'nCeLohFiLAo',
#  'XlecuiPh0v4',
#  'Qvfkw5bGfbs',
#  'SvZUHsetEOQ',
#  '6Xm-B6iJLZg',
#  '1L5FDGQmX9s',
#  'fxfhXX3T9Vc',
#  '-yjqibUcHb0',
#  'udgym2k0EiE',
#  'ZocqrON6qYs',
#  'V5oBl8aCa0Q',
#  'X4QWLS3ibAM',
#  'Gr-LqW4PCF4',
#  'hJF07Gppcm8',
#  'HqZCWUQqKS0',
#  '8HH5arJ-pfw',
#  '15ok9gyjGwA',
#  '3VYwpkrCVjQ',
#  'lCnMzY_T7Gw',
#  'SmFWlIhOEQY',
#  'uzFYSV2hbkg',
#  'so3TW7Xrq6Y',
#  'Qm9gFtYpHmQ',
#  'rrja9gJjkvQ',
#  '3gC4a3uudiA',
#  'ii1ynMwXiE8',
#  'FNTr1byW2Vg',
#  'tSGGFQN3a-A',
#  'kSoliKL1C_g',
#  ...]

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Parametress:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids
    
    
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
# This line of code calls the get_channel_stats() function with the youtube and channel_ids arguments, and assigns the returned channel statistics to the channel_stats variable.

channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#     channelName subscribers      views totalVideos                playlistId
# 0  David Bombal     1710000  106653492        1243  UUP7WmQ_U4GB3K51Od9QvM0w

# %%
# This function retrieves video details (e.g. view count, title, tags, duration) from a list of video IDs using the YouTube Data API, and stores them in a Pandas dataframe.

def get_video_details(youtube, video_ids):
    all_video_info = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {
                'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                'statistics': ['viewCount', 'likeCount', 'favoriteCount', 'commentCount'],
                'contentDetails': ['duration', 'definition', 'caption']
            }

            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)

    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)

# %%
video_df
# Out:
#          video_id  channelTitle  \
# 0     6mmgi65OjBM  David Bombal
# 1     5vDucASmO_I  David Bombal
# 2     unBOHR7BjwY  David Bombal
# 3     Zfz3ZN2dTDM  David Bombal
# 4     tm4evj8MZvY  David Bombal
# ...           ...           ...
# 1239  2iYr4YWq9sg  David Bombal
# 1240  pFZEClD438I  David Bombal
# 1241  S1yGGfyL1jU  David Bombal
# 1242  8DJhwKQpSE8  David Bombal
# 1243  _xtYk1jfJ3U  David Bombal
#
#                                                   title  \
# 0             What's the Best Operating System? #shorts
# 1     Flipper Zero Capture & Replay Sub-Ghz Signals ...
# 2             Do you know what a terminator is? #shorts
# 3     The best Hacking Courses & Certs (not all thes...
# 4                Pass or Fail? Does RAID actually work?
# ...                                                 ...
# 1239  Cisco ASA 7X Easy VPN made easy - VPN client A...
# 1240  Cisco Router Configurations made easy by Confi...
# 1241    Cisco ASA 7.X to ASA Site to Site VPN made easy
# 1242  Cisco ASA Easy VPN made easy - VPN client ASA VPN
# 1243        Cisco ASA to ASA Site to Site VPN made easy
#
#                                             description  \
# 0                        #youtubeshorts #linux #windows
# 1                 #youtubeshorts #flipperzero  #flipper
# 2                    #youtubeshorts #internet #starlink
# 3     This is your path to becoming a Pentester in 2...
# 4     Does a Synology NAS actually work? Should you ...
# ...                                                 ...
# 1239  See how to configure a Cisco ASA / PIX Easy VP...
# 1240  See how to configure a Cisco Router quickly an...
# 1241  See how to configure a Cisco ASA to ASA Site t...
# 1242  See how to configure a Cisco ASA / PIX Easy VP...
# 1243  See how to configure a Cisco ASA to ASA Site t...
#
#                                                    tags           publishedAt  \
# 0     [linux, ubuntu, windows, windows10, windows11,...  2023-03-19T15:00:03Z
# 1     [flipper zero, flipperzero, bluetooth, nfc, rf...  2023-03-14T15:01:00Z
# 2     [terminator, terminate, ethernet, 10base5, sta...  2023-03-09T15:00:40Z
# 3     [oscp, pnpt, pentester, hacker, hack, hacking,...  2023-03-05T15:00:31Z
# 4     [video, synology, sharing, nas, raid, video ph...  2023-02-24T15:00:48Z
# ...                                                 ...                   ...
# 1239  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-16T19:50:17Z
# 1240  [Cisco, CCNA, ICND, Router, Wireless, Pass, SS...  2008-09-15T21:37:22Z
# 1241  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T19:29:04Z
# 1242  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T19:04:52Z
# 1243  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T18:45:21Z
#
#      viewCount likeCount favoriteCount commentCount  duration definition  \
# 0       142138      6202             0          442     PT43S         hd
# 1        98592      6146             0           73     PT53S         hd
# 2        72155      3418             0          100     PT57S         hd
# 3       139734      6201             0          564  PT39M21S         hd
# 4        39891      1559             0          133  PT14M42S         hd
# ...        ...       ...           ...          ...       ...        ...
# 1239     10662        11             0            1   PT2M42S         sd
# 1240     34031        18             0            1   PT3M22S         sd
# 1241     12518        10             0            0   PT3M19S         sd
# 1242     40168        15             0            2      PT2M         sd
# 1243     61268       123             0           26   PT2M52S         sd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 1239   false
# 1240   false
# 1241   false
# 1242   false
# 1243   false
#
# [1244 rows x 13 columns]

# %%
playlist_ids = "UUP7WmQ_U4GB3K51Od9QvM0w"

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 1244

# %%
import googleapiclient.errors 
from googleapiclient.errors import HttpError

# %%
# This code defines a function get_comments_in_videos which takes a list of video ids and a YouTube API instance, and returns a Pandas DataFrame containing the comments for each video. It iterates through each video and extracts the comments using the YouTube API, and adds them to a list which is then converted into a DataFrame. If comments are disabled for a video, it skips that video and prints a message.

def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    for video_id in video_ids:
        try:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items']]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}
            all_comments.append(comments_in_video_info)
        except HttpError as error:
            if error.resp.status == 403:
                print(f"Comments disabled for video {video_id}. Skipping...")
            else:
                raise
    return pd.DataFrame(all_comments)

# %%
comments_df = get_comments_in_videos(youtube, video_ids)
# Out:
# Comments disabled for video 20_7tit3IBQ. Skipping...

# %%
comments_df

# %%
len(comments_df)

# %% [markdown]
# # Part II - Analysis

# %% [markdown]
# # Data pre-processing

# %%
# Checking for NULL values
video_df.isnull().any()
# Out:
# video_id         False
# channelTitle     False
# title            False
# description      False
# tags              True
# publishedAt      False
# viewCount        False
# likeCount        False
# favoriteCount    False
# commentCount     False
# duration         False
# definition       False
# caption          False
# dtype: bool

# %%
# Check data types
video_df.dtypes
# Out:
# video_id         object
# channelTitle     object
# title            object
# description      object
# tags             object
# publishedAt      object
# viewCount        object
# likeCount        object
# favoriteCount    object
# commentCount     object
# duration         object
# definition       object
# caption          object
# dtype: object

# %%
video_df
# Out:
#          video_id  channelTitle  \
# 0     6mmgi65OjBM  David Bombal
# 1     5vDucASmO_I  David Bombal
# 2     unBOHR7BjwY  David Bombal
# 3     Zfz3ZN2dTDM  David Bombal
# 4     tm4evj8MZvY  David Bombal
# ...           ...           ...
# 1239  2iYr4YWq9sg  David Bombal
# 1240  pFZEClD438I  David Bombal
# 1241  S1yGGfyL1jU  David Bombal
# 1242  8DJhwKQpSE8  David Bombal
# 1243  _xtYk1jfJ3U  David Bombal
#
#                                                   title  \
# 0             What's the Best Operating System? #shorts
# 1     Flipper Zero Capture & Replay Sub-Ghz Signals ...
# 2             Do you know what a terminator is? #shorts
# 3     The best Hacking Courses & Certs (not all thes...
# 4                Pass or Fail? Does RAID actually work?
# ...                                                 ...
# 1239  Cisco ASA 7X Easy VPN made easy - VPN client A...
# 1240  Cisco Router Configurations made easy by Confi...
# 1241    Cisco ASA 7.X to ASA Site to Site VPN made easy
# 1242  Cisco ASA Easy VPN made easy - VPN client ASA VPN
# 1243        Cisco ASA to ASA Site to Site VPN made easy
#
#                                             description  \
# 0                        #youtubeshorts #linux #windows
# 1                 #youtubeshorts #flipperzero  #flipper
# 2                    #youtubeshorts #internet #starlink
# 3     This is your path to becoming a Pentester in 2...
# 4     Does a Synology NAS actually work? Should you ...
# ...                                                 ...
# 1239  See how to configure a Cisco ASA / PIX Easy VP...
# 1240  See how to configure a Cisco Router quickly an...
# 1241  See how to configure a Cisco ASA to ASA Site t...
# 1242  See how to configure a Cisco ASA / PIX Easy VP...
# 1243  See how to configure a Cisco ASA to ASA Site t...
#
#                                                    tags           publishedAt  \
# 0     [linux, ubuntu, windows, windows10, windows11,...  2023-03-19T15:00:03Z
# 1     [flipper zero, flipperzero, bluetooth, nfc, rf...  2023-03-14T15:01:00Z
# 2     [terminator, terminate, ethernet, 10base5, sta...  2023-03-09T15:00:40Z
# 3     [oscp, pnpt, pentester, hacker, hack, hacking,...  2023-03-05T15:00:31Z
# 4     [video, synology, sharing, nas, raid, video ph...  2023-02-24T15:00:48Z
# ...                                                 ...                   ...
# 1239  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-16T19:50:17Z
# 1240  [Cisco, CCNA, ICND, Router, Wireless, Pass, SS...  2008-09-15T21:37:22Z
# 1241  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T19:29:04Z
# 1242  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T19:04:52Z
# 1243  [Cisco, ASA, PIX, VPN, IPSec, Site, to, EasyVP...  2008-09-14T18:45:21Z
#
#      viewCount likeCount favoriteCount commentCount  duration definition  \
# 0       142091      6200             0          442     PT43S         hd
# 1        98543      6136             0           73     PT53S         hd
# 2        72142      3414             0          100     PT57S         hd
# 3       139711      6201             0          564  PT39M21S         hd
# 4        39891      1559             0          133  PT14M42S         hd
# ...        ...       ...           ...          ...       ...        ...
# 1239     10662        11             0            1   PT2M42S         sd
# 1240     34031        18             0            1   PT3M22S         sd
# 1241     12518        10             0            0   PT3M19S         sd
# 1242     40168        15             0            2      PT2M         sd
# 1243     61268       123             0           26   PT2M52S         sd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 1239   false
# 1240   false
# 1241   false
# 1242   false
# 1243   false
#
# [1244 rows x 13 columns]

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)
print(video_df.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [114], in <cell line: 3>()
#       1 # Convert count columns to numeric
#       2 numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
# ----> 3 video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)
#       4 print(video_df.columns)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['favouriteCount'] not in index"

# %%
api_key = "AIzaSyAoXH-pggHWClrMsxLrgOOP0Fb0JHFcKNg"

def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    for video_id in video_ids:
        request = youtube.commentThreads().list(
            part="snippet,replies",
            videoId=video_id
        )
        response = request.execute()
        comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items']]
        comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}
        all_comments.append(comments_in_video_info)
    return pd.DataFrame(all_comments)

# %%
# Testing if requesting data from the Youtube channel works works

request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
response = request.execute()

JSON(response)

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)
